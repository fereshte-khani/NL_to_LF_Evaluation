# %% [markdown]
# # Uncovering Failures in Natural Language to Logical Form Translation Systems
#
# As the evolution of large language models (LLMs) continues to accelerate, new systems built on this technology are being developed daily. The questions that arise are - how can we measure their effectiveness? And how can we identify instances where they fall short? In this blog post, we will guide you through the process of swiftly identifying areas of failure in Natural Language to Logical Form Translation Systems.

# %% [markdown]
# Throughout this notebook, we'll be utilizing the Guidance library (https://github.com/microsoft/guidance) which simplifies the usage of large language models.
# With Guidance, you have the option to use {{parameter}} within a prompt to denote the specific parameter you intend to fill.
# Additionally, you can employ {{gen 'query'}} to instruct the LLM to generate content at that specific point for you.
# Below is a simple usecase of guidance, for more information, please refer to the guidance documentation.

# %%
import guidance
import os
import openai

# You should put your openai api key in ~/.openai_api_key

example2 = guidance("write a sentence about {{topic}}: {{gen 'results'}}! Now rewrite the {{results}} in poem style {{gen 'poem_results'}}", 
                    llm=guidance.llms.OpenAI("text-davinci-003"))
example2(topic='evaluation')
# Out:
# <div id="guidance-stop-button-34e7e927-a42d-4b65-a5df-969891977376" style="cursor: pointer; margin: 0px; display: none; float: right; padding: 3px; border-radius: 4px 4px 4px 4px; border: 0px solid rgba(127, 127, 127, 1); padding-left: 10px; padding-right: 10px; font-size: 13px; background-color: rgba(127, 127, 127, 0.25);">Stop program</div><div id="guidance-content-34e7e927-a42d-4b65-a5df-969891977376"><pre style='margin: 0px; padding: 0px; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'>write a sentence about <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{topic}}'>evaluation</span>: <span style='background-color: rgba(0, 165, 0, 0.25); opacity: 1.0; display: inline;' title='{{gen &#x27;results&#x27;}}'>
#
# The evaluation process is an important step in determining the success of a project.</span>! Now rewrite the <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{results}}'>
#
# The evaluation process is an important step in determining the success of a project.</span> in poem style <span style='background-color: rgba(0, 165, 0, 0.25); opacity: 1.0; display: inline;' title='{{gen &#x27;poem_results&#x27;}}'>
#
# Evaluation is key,
# To measure success, you see,
# For any project to be,
# It&#x27;s a must, you must agree.</span></pre></div>
# <script type="text/javascript">(()=>{var t={296:(t,e,n)=>{var i=NaN,o="[object Symbol]",r=/^\s+|\s+$/g,a=/^[-+]0x[0-9a-f]+$/i,s=/^0b[01]+$/i,c=/^0o[0-7]+$/i,d=parseInt,u="object"==typeof n.g&&n.g&&n.g.Object===Object&&n.g,l="object"==typeof self&&self&&self.Object===Object&&self,f=u||l||Function("return this")(),h=Object.prototype.toString,p=Math.max,m=Math.min,g=function(){return f.Date.now()};function b(t){var e=typeof t;return!!t&&("object"==e||"function"==e)}function y(t){if("number"==typeof t)return t;if(function(t){return"symbol"==typeof t||function(t){return!!t&&"object"==typeof t}(t)&&h.call(t)==o}(t))return i;if(b(t)){var e="function"==typeof t.valueOf?t.valueOf():t;t=b(e)?e+"":e}if("string"!=typeof t)return 0===t?t:+t;t=t.replace(r,"");var n=s.test(t);return n||c.test(t)?d(t.slice(2),n?2:8):a.test(t)?i:+t}t.exports=function(t,e,n){var i,o,r,a,s,c,d=0,u=!1,l=!1,f=!0;if("function"!=typeof t)throw new TypeError("Expected a function");function h(e){var n=i,r=o;return i=o=void 0,d=e,a=t.apply(r,n)}function v(t){var n=t-c;return void 0===c||n>=e||n<0||l&&t-d>=r}function _(){var t=g();if(v(t))return w(t);s=setTimeout(_,function(t){var n=e-(t-c);return l?m(n,r-(t-d)):n}(t))}function w(t){return s=void 0,f&&i?h(t):(i=o=void 0,a)}function j(){var t=g(),n=v(t);if(i=arguments,o=this,c=t,n){if(void 0===s)return function(t){return d=t,s=setTimeout(_,e),u?h(t):a}(c);if(l)return s=setTimeout(_,e),h(c)}return void 0===s&&(s=setTimeout(_,e)),a}return e=y(e)||0,b(n)&&(u=!!n.leading,r=(l="maxWait"in n)?p(y(n.maxWait)||0,e):r,f="trailing"in n?!!n.trailing:f),j.cancel=function(){void 0!==s&&clearTimeout(s),d=0,i=c=o=s=void 0},j.flush=function(){return void 0===s?a:w(g())},j}},777:t=>{var e,n,i=Math.max,o=(e=function(t,e){return function(t,e,n){if("function"!=typeof t)throw new TypeError("Expected a function");return setTimeout((function(){t.apply(void 0,n)}),1)}(t,0,e)},n=i(void 0===n?e.length-1:n,0),function(){for(var t=arguments,o=-1,r=i(t.length-n,0),a=Array(r);++o<r;)a[o]=t[n+o];o=-1;for(var s=Array(n+1);++o<n;)s[o]=t[o];return s[n]=a,function(t,e,n){switch(n.length){case 0:return t.call(e);case 1:return t.call(e,n[0]);case 2:return t.call(e,n[0],n[1]);case 3:return t.call(e,n[0],n[1],n[2])}return t.apply(e,n)}(e,this,s)});t.exports=o}},e={};function n(i){var o=e[i];if(void 0!==o)return o.exports;var r=e[i]={exports:{}};return t[i](r,r.exports,n),r.exports}n.n=t=>{var e=t&&t.__esModule?()=>t.default:()=>t;return n.d(e,{a:e}),e},n.d=(t,e)=>{for(var i in e)n.o(e,i)&&!n.o(t,i)&&Object.defineProperty(t,i,{enumerable:!0,get:e[i]})},n.g=function(){if("object"==typeof globalThis)return globalThis;try{return this||new Function("return this")()}catch(t){if("object"==typeof window)return window}}(),n.o=(t,e)=>Object.prototype.hasOwnProperty.call(t,e),(()=>{"use strict";const t=t=>{const e=new Set;do{for(const n of Reflect.ownKeys(t))e.add([t,n])}while((t=Reflect.getPrototypeOf(t))&&t!==Object.prototype);return e};function e(e,{include:n,exclude:i}={}){const o=t=>{const e=e=>"string"==typeof e?t===e:e.test(t);return n?n.some(e):!i||!i.some(e)};for(const[n,i]of t(e.constructor.prototype)){if("constructor"===i||!o(i))continue;const t=Reflect.getOwnPropertyDescriptor(n,i);t&&"function"==typeof t.value&&(e[i]=e[i].bind(e))}return e}var i=n(777),o=n.n(i),r=n(296),a=n.n(r);class s{constructor(t,n){e(this),this.interfaceId=t,this.callbackMap={},this.data={},this.pendingData={},this.jcomm=new c("guidance_interface_target_"+this.interfaceId,this.updateData,"open"),this.debouncedSendPendingData500=a()(this.sendPendingData,500),this.debouncedSendPendingData1000=a()(this.sendPendingData,1e3),n&&o()(n)}send(t,e){this.addPendingData(t,e),this.sendPendingData()}sendEvent(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.sendPendingData()}debouncedSendEvent500(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.debouncedSendPendingData500()}debouncedSend500(t,e){this.addPendingData(t,e),this.debouncedSendPendingData500()}debouncedS ...

# %% [markdown]
# Now let's assume you wrote the following prompt to translate natural language into SQL and your goal is to find examples that this prompt is failing!

# %%
# First you should define the table information for your database
table_info = """
There are 5 tables in the database with the following information:

Table name: user_details
Table columns: user_id,  user_name

Table name: journal_details
Table columns: journal_id, journal_name

Table name: publication_details
Table columns: publication_id, publication_name, publication_date, journal_id

Table name: author_list
Table columns: user_id, publication_id

Table name: citation_details
Table columns: publication_id1, publication_id2 
table information: publication_id1 cites publication_id2
"""

#Now you write a pompt that translate NL to LF. Guidance allows you to interact with LLMs in chat model using {{system}}, {{user}}, {{assistant}} tags
Natrual_question_to_sql_translator = guidance('''
{{#system~}}
You are an expert for SQL.
{{/system~}}

{{#user~}}
These are some information about tables in my database:

--
{{table_info}}
--

what is the SQL program to answer this question?
Question: {{question}}

Only write down the sql code no other text.
If you cannot generate a SQL program for this question then write down "out of scope"
{{/user~}}

{{#assistant~}}
{{gen 'answer'}}
{{~/assistant~}}''', 
llm=guidance.llms.OpenAI("gpt-3.5-turbo"))

# %% [markdown]
# For testing this prompt, we can manually check its performance on a few examples.

# %%
translation = Natrual_question_to_sql_translator(table_info = table_info, question='what is the average number of publications per author?');

translation['answer']
# Out:
# <div id="guidance-stop-button-aa60dae3-0047-47e5-ad9f-b526571e1309" style="cursor: pointer; margin: 0px; display: none; float: right; padding: 3px; border-radius: 4px 4px 4px 4px; border: 0px solid rgba(127, 127, 127, 1); padding-left: 10px; padding-right: 10px; font-size: 13px; background-color: rgba(127, 127, 127, 0.25);">Stop program</div><div id="guidance-content-aa60dae3-0047-47e5-ad9f-b526571e1309"><pre style='margin: 0px; padding: 0px; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are an expert for SQL.
# </div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>These are some information about tables in my database:
#
# --
# <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{table_info}}'>
# There are 5 tables in the database with the following information:
#
# Table name: user_details
# Table columns: user_id,  user_name
#
# Table name: journal_details
# Table columns: journal_id, journal_name
#
# Table name: publication_details
# Table columns: publication_id, publication_name, publication_date, journal_id
#
# Table name: author_list
# Table columns: user_id, publication_id
#
# Table name: citation_details
# Table columns: publication_id1, publication_id2
# table information: publication_id1 cites publication_id2
# </span>
# --
#
# what is the SQL program to answer this question?
# Question: <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{question}}'>what is the average number of publications per author?</span>
#
# Only write down the sql code no other text.
# If you cannot generate a SQL program for this question then write down &quot;out of scope&quot;
# </div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0, 165, 0, 0.25); opacity: 1.0; display: inline;' title='{{gen &#x27;answer&#x27;}}'>SELECT COUNT(publication_details.publication_id) / COUNT(DISTINCT author_list.user_id) AS avg_publications_per_author
# FROM publication_details
# INNER JOIN author_list ON publication_details.publication_id = author_list.publication_id;</span></div></div></pre></div>
# <script type="text/javascript">(()=>{var t={296:(t,e,n)=>{var i=NaN,o="[object Symbol]",r=/^\s+|\s+$/g,a=/^[-+]0x[0-9a-f]+$/i,s=/^0b[01]+$/i,c=/^0o[0-7]+$/i,d=parseInt,u="object"==typeof n.g&&n.g&&n.g.Object===Object&&n.g,l="object"==typeof self&&self&&self.Object===Object&&self,f=u||l||Function("return this")(),h=Object.prototype.toString,p=Math.max,m=Math.min,g=function(){return f.Date.now()};function b(t){var e=typeof t;return!!t&&("object"==e||"function"==e)}function y(t){if("number"==typeof t)return t;if(function(t){return"symbol"==typeof t||function(t){return!!t&&"object"==typeof t}(t)&&h.call(t)==o}(t))return i;if(b(t)){var e="function"==typeof t.valueOf?t.valueOf():t;t=b(e)?e+"":e}if("string"!=typeof t)return 0===t?t:+t;t=t.replace(r,"");var n=s.test(t);return n||c.test(t)?d(t.slice(2),n?2:8):a.test(t)?i:+t}t.exports=function(t,e,n){var i,o,r,a,s,c,d=0,u=!1,l=!1,f=!0;if("function"!=typeof t)throw new TypeError("Expected a function");function h(e){var n=i,r=o;return i=o=void 0,d=e,a=t.apply(r,n)}function v(t){var n=t-c;return void 0===c||n>=e||n<0||l&&t-d>=r}function _(){var t=g();if(v(t))return w(t);s=setTimeout(_,function(t){var n=e-(t-c);return l?m(n,r-(t-d)):n}(t))}function w(t){return s=void 0,f&&i?h(t):(i=o=void 0,a)}function j(){var t=g(),n=v(t);if(i=arguments,o=this,c=t,n){if(void 0===s)return function(t){return d=t,s=setTimeout(_,e),u?h(t):a}(c);if(l)return s=setTimeout(_,e),h(c)}return void 0===s&&(s=setTimeout(_,e)),a}return e=y(e)||0,b(n)&&(u=!!n.leading,r=(l="maxWait"in n)?p(y(n.maxWait)||0,e):r,f="trailing"in n?!!n.trailing:f),j.cancel=function(){void 0!==s&&clearTimeout(s),d=0,i=c=o=s=void 0},j.flush=function(){return void 0===s?a:w(g())},j}},777:t=>{var e,n,i=Math.max,o=(e=function(t,e){return function(t,e,n){if("function"!=typeof t)throw new TypeError("Expected a function");return setTimeout((function(){t.apply(void 0,n)}),1)}(t,0,e)},n=i(void 0===n?e.length-1:n,0),function(){for(var t=arguments,o=-1,r=i(t.length-n,0),a=Array(r);++o<r;)a[o]=t[n+o];o=-1;for(var s=Array(n+1);++o<n;)s[o]=t[o];return s[n]=a,function(t,e,n){switch(n.length){case 0:return t.call(e);case 1:return t.call(e,n[0]);case 2:return t.call(e,n[0],n[1]);case 3:return t.call(e,n[0],n[1],n[2])}return t.apply(e,n)}(e,this,s)});t.exports=o}},e={};function n(i){var o=e[i];if(void 0!==o)return o.exports;var r=e[i]={exports:{}};return t[i](r,r.exports,n),r.exports}n.n=t=>{var e=t&&t.__esModule?()=>t.default:()=>t;return n.d(e,{a:e}),e},n.d=(t,e)=>{for(var i in e)n.o(e,i)&&!n.o(t,i)&&Object.defineProperty(t,i,{enumerable:!0,get:e[i]})},n.g=function(){if("object"==typeof globalThis)return globalThis;try{return this||new Function("return this")()}catch(t){if("object"==typeof window)return window}}(),n.o=(t,e)=>Object.prototype.hasOwnProperty.call(t,e),(()=>{"use strict";const t=t=>{const e=new Set;do{for(const n of Reflect.ownKeys(t))e.add([t,n])}while((t=Reflect.getPrototypeOf(t))&&t!==Object.prototype);return e};function e(e,{include:n,exclude:i}={}){const o=t=>{const e=e=>"string"==typeof e?t===e:e.test(t);return n?n.some(e):!i||!i.some(e)};for(const[n,i]of t(e.constructor.prototype)){if("constructor"===i||!o(i))continue;const t=Reflect.getOwnPropertyDescriptor(n,i);t&&"function"==typeof t.value&&(e[i]=e[i].bind(e))}return e}var i=n(777),o=n.n(i),r=n(296),a=n.n(r);class s{constructor(t,n){e(this),this.interfaceId=t,this.callbackMap={},this.data={},this.pendingData={},this.jcomm=new c("guidance_interface_target_"+this.interfaceId,this.updateData,"open"),this.debouncedSendPendingData500=a()(this.sendPendingData,500),this.debouncedSendPendingData1000=a()(this.sendPendingData,1e3),n&&o()(n)}send(t,e){this.addPendingData(t,e),this.sendPendingData()}sendEvent(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.sendPendingData()}debouncedSendEvent500(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.debouncedSendPendingData500()}debouncedSend500(t,e){this.addPendingData(t,e),this.debouncedSendPendingData500()}debouncedS ...
# 'SELECT COUNT(publication_details.publication_id) / COUNT(DISTINCT author_list.user_id) AS avg_publications_per_author\nFROM publication_details\nINNER JOIN author_list ON publication_details.publication_id = author_list.publication_id;'

# %% [markdown]
# Checking the performance of prompt manually like this is not efficient, how can we make this better?
# Instead of writing the examples manually, we can use an LLM to find examples.
# Consider the following prompt for generating a variaty of examples:

# %%
generate_natrual_language_questions = guidance('''
{{#system~}}
You are an expert for SQL.
{{~/system~}}

{{#user~}}
Generate a variety of questions in natural language that one can ask given these tables information: 
-- table information --
{{table_info}}
-- end of table information --

Please write {{num_questions}} diverse and real questions spanning as many use cases as possible, one question in each line no other text. 
write in the format of 1., 2., etc.
Note that users do not have access to the table information, so they don't know how tables look like. They are just wondering about some questions.
Try to make the questions specific; so, use specific publication names e.g., 'collaborative development of NLP' instead of 'particular publication'.
Similarly, use specific names for users and journals. i.e., try to come up with some potentail names for them. 
Try to make some of your questions simple and some very complex and compositional.
remeber to write one question in each line and no other text.

{{#if contain_examples}} 
These are some example questions: 
{{examples}} 
{{/if}}
{{~/user~}}

{{#assistant~}}
{{gen 'answer' n=1 temperature=1.0}}
{{~/assistant~}} 
''', llm=guidance.llms.OpenAI("gpt-3.5-turbo"))

generate_natrual_language_questions(table_info = table_info, 
                                    num_questions=10, 
                                    contain_examples=True, 
                                    examples='How many publications Alice wrote since 2002?\nWhen was the last time Alice Wu collaborated with Percy Liang?');
# Out:
# <div id="guidance-stop-button-e307f543-0438-4785-864b-c09ab3cbf989" style="cursor: pointer; margin: 0px; display: none; float: right; padding: 3px; border-radius: 4px 4px 4px 4px; border: 0px solid rgba(127, 127, 127, 1); padding-left: 10px; padding-right: 10px; font-size: 13px; background-color: rgba(127, 127, 127, 0.25);">Stop program</div><div id="guidance-content-e307f543-0438-4785-864b-c09ab3cbf989"><pre style='margin: 0px; padding: 0px; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are an expert for SQL.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Generate a variety of questions in natural language that one can ask given these tables information:
# -- table information --
# <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{table_info}}'>
# There are 5 tables in the database with the following information:
#
# Table name: user_details
# Table columns: user_id,  user_name
#
# Table name: journal_details
# Table columns: journal_id, journal_name
#
# Table name: publication_details
# Table columns: publication_id, publication_name, publication_date, journal_id
#
# Table name: author_list
# Table columns: user_id, publication_id
#
# Table name: citation_details
# Table columns: publication_id1, publication_id2
# table information: publication_id1 cites publication_id2
# </span>
# -- end of table information --
#
# Please write <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{num_questions}}'>10</span> diverse and real questions spanning as many use cases as possible, one question in each line no other text.
# write in the format of 1., 2., etc.
# Note that users do not have access to the table information, so they don&#x27;t know how tables look like. They are just wondering about some questions.
# Try to make the questions specific; so, use specific publication names e.g., &#x27;collaborative development of NLP&#x27; instead of &#x27;particular publication&#x27;.
# Similarly, use specific names for users and journals. i.e., try to come up with some potentail names for them.
# Try to make some of your questions simple and some very complex and compositional.
# remeber to write one question in each line and no other text.
#
# <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{#if contain_examples}}
# These are some example questions:
# {{examples}}
# {{/if}}'>
# These are some example questions:
# <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{examples}}'>How many publications Alice wrote since 2002?
# When was the last time Alice Wu collaborated with Percy Liang?</span>
# </span></div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0, 165, 0, 0.25); opacity: 1.0; display: inline;' title='{{gen &#x27;answer&#x27; n=1 temperature=1.0}}'>1. Who are the authors of the publication &quot;Neural Networks for Machine Translation&quot;?
# 2. What are the names of all journals in the database?
# 3. How many authors have published in the &quot;Journal of Computer Science&quot;?
# 4. Which publications cite &quot;Distributed Representations of Sentences and Documents&quot;?
# 5. How many publications have been authored by both &quot;Andrew Ng&quot; and &quot;Yoshua Bengio&quot;?
# 6. Who are the authors of a publication that &quot;Alice Smith&quot; has cited?
# 7. What is the total number of publications in the database?
# 8. What are the names of all authors who have published in the &quot;Journal of Artificial Intelligence&quot; before 2010?
# 9. Which users have not authored any publications?
# 10. How many publications were authored by users who have not cited any publications?</span></div></div></pre></div>
# <script type="text/javascript">(()=>{var t={296:(t,e,n)=>{var i=NaN,o="[object Symbol]",r=/^\s+|\s+$/g,a=/^[-+]0x[0-9a-f]+$/i,s=/^0b[01]+$/i,c=/^0o[0-7]+$/i,d=parseInt,u="object"==typeof n.g&&n.g&&n.g.Object===Object&&n.g,l="object"==typeof self&&self&&self.Object===Object&&self,f=u||l||Function("return this")(),h=Object.prototype.toString,p=Math.max,m=Math.min,g=function(){return f.Date.now()};function b(t){var e=typeof t;return!!t&&("object"==e||"function"==e)}function y(t){if("number"==typeof t)return t;if(function(t){return"symbol"==typeof t||function(t){return!!t&&"object"==typeof t}(t)&&h.call(t)==o}(t))return i;if(b(t)){var e="function"==typeof t.valueOf?t.valueOf():t;t=b(e)?e+"":e}if("string"!=typeof t)return 0===t?t:+t;t=t.replace(r,"");var n=s.test(t);return n||c.test(t)?d(t.slice(2),n?2:8):a.test(t)?i:+t}t.exports=function(t,e,n){var i,o,r,a,s,c,d=0,u=!1,l=!1,f=!0;if("function"!=typeof t)throw new TypeError("Expected a function");function h(e){var n=i,r=o;return i=o=void 0,d=e,a=t.apply(r,n)}function v(t){var n=t-c;return void 0===c||n>=e||n<0||l&&t-d>=r}function _(){var t=g();if(v(t))return w(t);s=setTimeout(_,function(t){var n=e-(t-c);return l?m(n,r-(t-d)):n}(t))}function w(t){return s=void 0,f&&i?h(t):(i=o=void 0,a)}function j(){var t=g(),n=v(t);if(i=arguments,o=this,c=t,n){if(void 0===s)return function(t){return d=t,s=setTimeout(_,e),u?h(t):a}(c);if(l)return s=setTimeout(_,e),h(c)}return void 0===s&&(s=setTimeout(_,e)),a}return e=y(e)||0,b(n)&&(u=!!n.leading,r=(l="maxWait"in n)?p(y(n.maxWait)||0,e):r,f="trailing"in n?!!n.trailing:f),j.cancel=function(){void 0!==s&&clearTimeout(s),d=0,i=c=o=s=void 0},j.flush=function(){return void 0===s?a:w(g())},j}},777:t=>{var e,n,i=Math.max,o=(e=function(t,e){return function(t,e,n){if("function"!=typeof t)throw new TypeError("Expected a function");return setTimeout((function(){t.apply(void 0,n)}),1)}(t,0,e)},n=i(void 0===n?e.length-1:n,0),function(){for(var t=arguments,o=-1,r=i(t.length-n,0),a=Array(r);++o<r;)a[o]=t[n+o];o=-1;for(var s=Array(n+1);++o<n;)s[o]=t[o];return s[n]=a,function(t,e,n){switch(n.length){case 0:return t.call(e);case 1:return t.call(e,n[0]);case 2:return t.call(e,n[0],n[1]);case 3:return t.call(e,n[0],n[1],n[2])}return t.apply(e,n)}(e,this,s)});t.exports=o}},e={};function n(i){var o=e[i];if(void 0!==o)return o.exports;var r=e[i]={exports:{}};return t[i](r,r.exports,n),r.exports}n.n=t=>{var e=t&&t.__esModule?()=>t.default:()=>t;return n.d(e,{a:e}),e},n.d=(t,e)=>{for(var i in e)n.o(e,i)&&!n.o(t,i)&&Object.defineProperty(t,i,{enumerable:!0,get:e[i]})},n.g=function(){if("object"==typeof globalThis)return globalThis;try{return this||new Function("return this")()}catch(t){if("object"==typeof window)return window}}(),n.o=(t,e)=>Object.prototype.hasOwnProperty.call(t,e),(()=>{"use strict";const t=t=>{const e=new Set;do{for(const n of Reflect.ownKeys(t))e.add([t,n])}while((t=Reflect.getPrototypeOf(t))&&t!==Object.prototype);return e};function e(e,{include:n,exclude:i}={}){const o=t=>{const e=e=>"string"==typeof e?t===e:e.test(t);return n?n.some(e):!i||!i.some(e)};for(const[n,i]of t(e.constructor.prototype)){if("constructor"===i||!o(i))continue;const t=Reflect.getOwnPropertyDescriptor(n,i);t&&"function"==typeof t.value&&(e[i]=e[i].bind(e))}return e}var i=n(777),o=n.n(i),r=n

# %% [markdown]
# We can now use the output of this prompt to evaluate the performance of the original prompt.
# But still checking the sql of every single example is not efficient.
# How about asking the LLM to check the sql for us?
# For doing so, we write two more prompts:
# - **SQL_translator**: a prompt that generates a natrual language question from a sql
# - **Similarity Checker**: a prompt that given two questions tell us how much these two questions are similar to each other.

# %%
#SQL_transalator: translate a sql code to natrual question
sql_translator = guidance('''
{{#system~}}
You are an expert for SQL.
{{/system~}}

{{#user~}}
This is my table information:
-- table information --
{{table_info}}
-- end of table information --

What a user might have asked that resulted in the following SQL code? 
sql code: {{question}}
only write down the potentail question no other text. Remeber to write down the question in a way that a human might ask.
{{/user~}}

{{#assistant~}}
{{gen 'answer'}}
{{/assistant~}}
''', llm=guidance.llms.OpenAI("gpt-3.5-turbo"))


# analyse two questions and see how much they are similar
similarity_checker = guidance('''
{{#system~}}
You are a very helpful assistant.
{{/system~}}

{{#user~}}
I have the following database with these table information:
----
{{table_info}}
----

I have two questions and I want you to tell me how similar they are. 
In particular I want to know if they are asking the same thing in my database. (i.e., if I run them on my database will they return the same result?)

question 1: {{question1}}
question 2: {{question2}}

Are these two questions asking the same thing or not? 
Just answer with a number between 0 and 100 where 0 means they are completely different and 100 means they are exactly the same.
please do not write any other text.
{{/user~}}

{{#assistant~}}
{{gen 'answer'}}
{{/assistant~}}
''', llm=guidance.llms.OpenAI("gpt-3.5-turbo"))

# %% [markdown]
# I can now use these three prompts to find examples that the original prompt might fail on them.
# First let's define a function that given an example, it gives us a number of how much the original prompt might fail on this example

# %%
def correctness(q):
    print('the question is:\n', q)
    LF_translation = Natrual_question_to_sql_translator(table_info=table_info, 
                           question=q)
    print('\nthe generated sql:\n', LF_translation['answer'].strip())
    if('out of scope' in LF_translation['answer'].strip()):
        return (q, 'out of scope', LF_translation['answer'], 100)

    reverse_question = sql_translator(table_info=table_info, question=LF_translation['answer'])

    print('\nthe reverse question is:\n', reverse_question['answer'].strip())
    similarity = similarity_checker(table_info= table_info, question1=q, question2=reverse_question['answer'])
    print('\nthe similarity score is:\n', similarity['answer'].strip())
    return (q, reverse_question['answer'], LF_translation['answer'], int(similarity['answer'].strip()))

# %% [markdown]
# Now we are using this correcteness function to find failures!

# %%
def normal_evaluation(num_rounds, q_in_each_round=10):
    tests = []
    for i in range(num_rounds):
        print(f'---------round:{i}-------------')
        guidance.llms.OpenAI.cache.clear() #guidance always cache the answer for efficiency! however here we don't want to cache since we want different set of examples in each round

        questions = generate_natrual_language_questions(table_info=table_info, num_questions=q_in_each_round, examples=None, contain_examples=False)
        #remove the question number from each question
        questions = questions['answer'].split('\n')
        questions = [q.split('. ', 1)[1] for q in questions]
        for q in questions:
            tests.append(correctness(q))
    #sort the questions based on their difficulty
    return tests

# %%
tests = normal_evaluation(num_rounds=10,q_in_each_round=5)

# %% [markdown]
# We write a simple function to investiage examples that their similarity score is les than some threshold.

# %%
def investigate(tests, treshold = 80):
    tests = sorted(tests, key=lambda x: x[3]) # sort tests by their similarity
    num_failure = 0
    for t in tests:
        if t[3] < treshold:
            print(t[0])
            print(t[1])
            print(t[2])
            print(t[3])
            num_failure += 1
            print('------------------')
        else:
            break
    print('failures rate: ', num_failure / len(tests), num_failure, len(tests))

investigate(tests)
# Out:
# What is the name of the journal with the latest publication?
# What is the latest journal that a publication was published in?
# SELECT journal_name
# FROM journal_details
# WHERE journal_id = (SELECT journal_id
#                     FROM publication_details
#                     ORDER BY publication_date DESC
#                     LIMIT 1);
# 70
# ------------------
# List all the publications that have been cited by any publication authored by 'Anna Smith' but have not been cited by any publication authored by 'John Davis'.
# What are the publications that Anna Smith has authored and cited, but John Davis has not cited?
# SELECT DISTINCT p.publication_id, p.publication_name
# FROM publication_details p
# INNER JOIN author_list a ON p.publication_id = a.publication_id
# INNER JOIN citation_details c ON p.publication_id = c.publication_id2
# WHERE a.user_id = (SELECT user_id FROM user_details WHERE user_name = 'Anna Smith')
# AND p.publication_id NOT IN (
#     SELECT p2.publication_id
#     FROM publication_details p2
#     INNER JOIN author_list a2 ON p2.publication_id = a2.publication_id
#     INNER JOIN citation_details c2 ON p2.publication_id = c2.publication_id1
#     WHERE a2.user_id = (SELECT user_id FROM user_details WHERE user_name = 'John Davis')
# )
# 70
# ------------------
# How many different users have authored the publications that have been published in the journal 'IEEE access' before the year 2020?
# "How many unique users have published in the journal 'IEEE access' before 2020?"
# SELECT COUNT(DISTINCT user_id)
# FROM author_list
# WHERE publication_id IN
#     (SELECT publication_id
#      FROM publication_details
#      WHERE journal_id =
#          (SELECT journal_id
#           FROM journal_details
#           WHERE journal_name = 'IEEE access')
#      AND publication_date < '2020-01-01');
# 70
# ------------------
# How many publications authored by "John Doe" are cited by "Collaborative Development of Natural Language Processing Frameworks"?
# What is the count of distinct publications cited by articles published in the journal "Collaborative Development of Natural Language Processing Frameworks" by the user "John Doe"?
# SELECT COUNT(DISTINCT cd.publication_id2)
# FROM citation_details cd
# JOIN author_list al ON cd.publication_id2 = al.publication_id
# JOIN user_details ud ON al.user_id = ud.user_id
# JOIN publication_details pd ON cd.publication_id1 = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE ud.user_name = 'John Doe' AND jd.journal_name = 'Collaborative Development of Natural Language Processing Frameworks'
# 70
# ------------------
# Which publication "Collaborative Development of NLP" has been cited the most by other publications?
# What is the citation count for the publication "Collaborative Development of NLP" and which publication has the highest citation count?
# SELECT publication_name, COUNT(publication_id2) AS citation_count
# FROM publication_details
# JOIN citation_details ON publication_details.publication_id = citation_details.publication_id2
# WHERE publication_name = 'Collaborative Development of NLP'
# GROUP BY publication_name
# ORDER BY citation_count DESC
# LIMIT 1;
# 70
# ------------------
# Which user has co-authored the most publications with the user "Jack Smith"?
# Who is the most frequent co-author of Jack Smith in terms of publications?
# SELECT ul.user_id, COUNT(*) AS coauthored_publications
# FROM author_list AS al
# JOIN author_list AS ul ON al.publication_id = ul.publication_id
# WHERE al.user_id = 'Jack Smith' AND ul.user_id != 'Jack Smith'
# GROUP BY ul.user_id
# ORDER BY coauthored_publications DESC
# LIMIT 1;
# 70
# ------------------
# How many publications that were published in the journal 'Nature Communications' have been cited by the publication 'Genome-Wide Analysis of Gene Expression in Yeast'?
# "How many times has the publication 'Genome-Wide Analysis of Gene Expression in Yeast' been cited in articles published in the journal 'Nature Communications'?"
# SELECT COUNT(*)
# FROM citation_details
# WHERE publication_id2 = (SELECT publication_id
#                          FROM publication_details
#                          WHERE publication_name = 'Genome-Wide Analysis of Gene Expression in Yeast')
# AND publication_id1 IN (SELECT publication_id
#                         FROM publication_details
#                         WHERE journal_id = (SELECT journal_id
#                                             FROM journal_details
#                                             WHERE journal_name = 'Nature Communications'));
# 70
# ------------------
# Which publications are cited by both "Advancements in Natural Language Processing" and "Collaborative development of NLP"?
# What are the publications that have been cited by "Advancements in Natural Language Processing" and have cited "Collaborative development of NLP"?
# SELECT DISTINCT cd.publication_id2
# FROM citation_details cd
# INNER JOIN publication_details pd ON cd.publication_id2 = pd.publication_id
# INNER JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE pd.publication_name = 'Advancements in Natural Language Processing'
# AND cd.publication_id1 IN (SELECT publication_id FROM publication_details WHERE publication_name = 'Collaborative development of NLP')
# 70
# ------------------
# Which user has the most publications published in the year 2021?
# "Who is the top author in 2021 based on the number of publications they have?"
# SELECT user_details.user_name, COUNT(publication_details.publication_id) AS num_publications
# FROM user_details
# JOIN author_list ON user_details.user_id = author_list.user_id
# JOIN publication_details ON author_list.publication_id = publication_details.publication_id
# WHERE YEAR(publication_details.publication_date) = 2021
# GROUP BY user_details.user_name
# ORDER BY num_publications DESC
# LIMIT 1;
# 70
# ------------------
# failures rate:  0.18 9 50

# %% [markdown]
# This method allows us to find failures with failure rate 0.14! Can we make it more efficient?
# In the following we choose examples that have low correctness score and use them as an examples for the NL_generator.
# This allows the NL_generator to generate more failures (thus higher failure rate).

# %%
def greedy_evaluation(num_rounds, q_in_each_round=10):
    tests_sorted = []
    for i in range(num_rounds):
        print(f'---------round:{i}-------------')
        if(tests_sorted == []):
            questions = generate_natrual_language_questions(table_info=table_info, num_questions=q_in_each_round, examples=None, contain_examples=False)
        else:
            #choose top 10 questions (first item) of the tests_sorted
            examples = [x[0] for x in tests_sorted[0:5]]
            questions = generate_natrual_language_questions(table_info=table_info, num_questions=q_in_each_round, examples=examples, contain_examples=True)
        #remove the question number from each question
        questions = questions['answer'].split('\n')
        questions = [q.split('. ', 1)[1] for q in questions]
        for q in questions:
            tests_sorted.append(correctness(q))
        #sort tests_sorted by the second item
        tests_sorted = sorted(tests_sorted, key=lambda x: x[3])
    return tests_sorted

# %%
greedy_tests = greedy_evaluation(num_rounds=10, q_in_each_round=5)
# Out:
# <div id="guidance-stop-button-51390aae-68a2-4a19-a999-c8d1a01fddf9" style="cursor: pointer; margin: 0px; display: none; float: right; padding: 3px; border-radius: 4px 4px 4px 4px; border: 0px solid rgba(127, 127, 127, 1); padding-left: 10px; padding-right: 10px; font-size: 13px; background-color: rgba(127, 127, 127, 0.25);">Stop program</div><div id="guidance-content-51390aae-68a2-4a19-a999-c8d1a01fddf9"><pre style='margin: 0px; padding: 0px; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are a very helpful assistant.
# </div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>I have the following database with these table information:
# ----
# <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{table_info}}'>
# There are 5 tables in the database with the following information:
#
# Table name: user_details
# Table columns: user_id,  user_name
#
# Table name: journal_details
# Table columns: journal_id, journal_name
#
# Table name: publication_details
# Table columns: publication_id, publication_name, publication_date, journal_id
#
# Table name: author_list
# Table columns: user_id, publication_id
#
# Table name: citation_details
# Table columns: publication_id1, publication_id2
# table information: publication_id1 cites publication_id2
# </span>
# ----
#
# I have two questions and I want you to tell me how similar they are.
# In particular I want to know if they are asking the same thing in my database. (i.e., if I run them on my database will they return the same result?)
#
# question 1: <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{question1}}'>Which journals have published papers co-authored by user &quot;Michael&quot; and the publication names have the word &quot;neural network&quot; in them?</span>
# question 2: <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{question2}}'>What are the names of the journals that Michael has published articles related to neural networks in?</span>
#
# Are these two questions asking the same thing or not?
# Just answer with a number between 0 and 100 where 0 means they are completely different and 100 means they are exactly the same.
# please do not write any other text.
# </div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0, 165, 0, 0.25); opacity: 1.0; display: inline;' title='{{gen &#x27;answer&#x27;}}'>70</span>
# </div></div></pre></div>
# <script type="text/javascript">(()=>{var t={296:(t,e,n)=>{var i=NaN,o="[object Symbol]",r=/^\s+|\s+$/g,a=/^[-+]0x[0-9a-f]+$/i,s=/^0b[01]+$/i,c=/^0o[0-7]+$/i,d=parseInt,u="object"==typeof n.g&&n.g&&n.g.Object===Object&&n.g,l="object"==typeof self&&self&&self.Object===Object&&self,f=u||l||Function("return this")(),h=Object.prototype.toString,p=Math.max,m=Math.min,g=function(){return f.Date.now()};function b(t){var e=typeof t;return!!t&&("object"==e||"function"==e)}function y(t){if("number"==typeof t)return t;if(function(t){return"symbol"==typeof t||function(t){return!!t&&"object"==typeof t}(t)&&h.call(t)==o}(t))return i;if(b(t)){var e="function"==typeof t.valueOf?t.valueOf():t;t=b(e)?e+"":e}if("string"!=typeof t)return 0===t?t:+t;t=t.replace(r,"");var n=s.test(t);return n||c.test(t)?d(t.slice(2),n?2:8):a.test(t)?i:+t}t.exports=function(t,e,n){var i,o,r,a,s,c,d=0,u=!1,l=!1,f=!0;if("function"!=typeof t)throw new TypeError("Expected a function");function h(e){var n=i,r=o;return i=o=void 0,d=e,a=t.apply(r,n)}function v(t){var n=t-c;return void 0===c||n>=e||n<0||l&&t-d>=r}function _(){var t=g();if(v(t))return w(t);s=setTimeout(_,function(t){var n=e-(t-c);return l?m(n,r-(t-d)):n}(t))}function w(t){return s=void 0,f&&i?h(t):(i=o=void 0,a)}function j(){var t=g(),n=v(t);if(i=arguments,o=this,c=t,n){if(void 0===s)return function(t){return d=t,s=setTimeout(_,e),u?h(t):a}(c);if(l)return s=setTimeout(_,e),h(c)}return void 0===s&&(s=setTimeout(_,e)),a}return e=y(e)||0,b(n)&&(u=!!n.leading,r=(l="maxWait"in n)?p(y(n.maxWait)||0,e):r,f="trailing"in n?!!n.trailing:f),j.cancel=function(){void 0!==s&&clearTimeout(s),d=0,i=c=o=s=void 0},j.flush=function(){return void 0===s?a:w(g())},j}},777:t=>{var e,n,i=Math.max,o=(e=function(t,e){return function(t,e,n){if("function"!=typeof t)throw new TypeError("Expected a function");return setTimeout((function(){t.apply(void 0,n)}),1)}(t,0,e)},n=i(void 0===n?e.length-1:n,0),function(){for(var t=arguments,o=-1,r=i(t.length-n,0),a=Array(r);++o<r;)a[o]=t[n+o];o=-1;for(var s=Array(n+1);++o<n;)s[o]=t[o];return s[n]=a,function(t,e,n){switch(n.length){case 0:return t.call(e);case 1:return t.call(e,n[0]);case 2:return t.call(e,n[0],n[1]);case 3:return t.call(e,n[0],n[1],n[2])}return t.apply(e,n)}(e,this,s)});t.exports=o}},e={};function n(i){var o=e[i];if(void 0!==o)return o.exports;var r=e[i]={exports:{}};return t[i](r,r.exports,n),r.exports}n.n=t=>{var e=t&&t.__esModule?()=>t.default:()=>t;return n.d(e,{a:e}),e},n.d=(t,e)=>{for(var i in e)n.o(e,i)&&!n.o(t,i)&&Object.defineProperty(t,i,{enumerable:!0,get:e[i]})},n.g=function(){if("object"==typeof globalThis)return globalThis;try{return this||new Function("return this")()}catch(t){if("object"==typeof window)return window}}(),n.o=(t,e)=>Object.prototype.hasOwnProperty.call(t,e),(()=>{"use strict";const t=t=>{const e=new Set;do{for(const n of Reflect.ownKeys(t))e.add([t,n])}while((t=Reflect.getPrototypeOf(t))&&t!==Object.prototype);return e};function e(e,{include:n,exclude:i}={}){const o=t=>{const e=e=>"string"==typeof e?t===e:e.test(t);return n?n.some(e):!i||!i.some(e)};for(const[n,i]of t(e.constructor.prototype)){if("constructor"===i||!o(i))continue;const t=Reflect.getOwnPropertyDescriptor(n,i);t&&"function"==typeof t.value&&(e[i]=e[i].bind(e))}return e}var i=n(777),o=n.n(i),r=n(296),a=n.n(r);class s{constructor(t,n){e(this),this.interfaceId=t,this.callbackMap={},this.data={},this.pendingData={},this.jcomm=new c("guidance_interface_target_"+this.interfaceId,this.updateData,"open"),this.debouncedSendPendingData500=a()(this.sendPendingData,500),this.debouncedSendPendingData1000=a()(this.sendPendingData,1e3),n&&o()(n)}send(t,e){this.addPendingData(t,e),this.sendPendingData()}sendEvent(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.sendPendingData()}debouncedSendEvent500(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.debouncedSendPendingData500()}debouncedSend500(t,e){this.addPendingData(t,e),this.debouncedSendPendingData500()}debouncedS ...
# the similarity score is:
#  70

# %%
investigate(greedy_tests)
# Out:
# How many authors have published in a journal based in Europe before the year 2000?
# "How many unique users have published in European journals before the year 2000?"
# SELECT COUNT(DISTINCT user_id)
# FROM author_list
# JOIN publication_details ON author_list.publication_id = publication_details.publication_id
# JOIN journal_details ON publication_details.journal_id = journal_details.journal_id
# WHERE publication_details.publication_date < '2000-01-01' AND journal_details.journal_name LIKE '%Europe%'
# 50
# ------------------
# How many authors have published in multiple journals and at least one of their publications is cited by another publication in the database?
# How many unique authors have published papers that cite papers published in different journals?
# SELECT COUNT(DISTINCT al.user_id)
# FROM author_list al
# INNER JOIN publication_details pd1 ON al.publication_id = pd1.publication_id
# INNER JOIN publication_details pd2 ON pd1.publication_id <> pd2.publication_id AND pd1.journal_id <> pd2.journal_id AND pd1.publication_id = citation_details.publication_id1 AND pd2.publication_id = citation_details.publication_id2
# 50
# ------------------
# Who are the authors that have never been cited by any other publications in the database?
# Which users have not cited any publications?
# SELECT DISTINCT user_details.user_name
# FROM user_details
# INNER JOIN author_list ON user_details.user_id = author_list.user_id
# LEFT JOIN citation_details ON author_list.publication_id = citation_details.publication_id2
# WHERE citation_details.publication_id1 IS NULL;
# 50
# ------------------
# Which authors have not published any papers in the past year?
# What are the names of users who have not published any articles in the last year or have never published any articles?
# SELECT DISTINCT user_details.user_name
# FROM user_details
# LEFT JOIN author_list ON user_details.user_id = author_list.user_id
# LEFT JOIN publication_details ON author_list.publication_id = publication_details.publication_id
# WHERE publication_details.publication_date < DATEADD(year, -1, GETDATE()) OR publication_details.publication_date IS NULL
# 70
# ------------------
# Which publication has the most citations and is co-authored by a user named 'John'?
# What is the most cited publication that has been authored by John?
# SELECT publication_id2, COUNT(*) AS citation_count
# FROM citation_details
# GROUP BY publication_id2
# HAVING publication_id2 IN (
#   SELECT publication_id
#   FROM author_list
#   JOIN user_details ON author_list.user_id = user_details.user_id
#   WHERE user_name = 'John'
# )
# ORDER BY citation_count DESC
# LIMIT 1;
# 70
# ------------------
# What is the name of the journal that published the most publications co-authored by a user named 'Sarah'?
# What is the most popular journal among publications authored by Sarah?
# SELECT journal_details.journal_name
# FROM journal_details
# JOIN publication_details ON journal_details.journal_id = publication_details.journal_id
# JOIN author_list ON publication_details.publication_id = author_list.publication_id
# JOIN user_details ON author_list.user_id = user_details.user_id
# WHERE user_details.user_name = 'Sarah'
# GROUP BY journal_details.journal_name
# ORDER BY COUNT(*) DESC
# LIMIT 1;
# 70
# ------------------
# How many authors have published a paper in a journal before the year 2000 and later cited a publication that was published after the year 2020?
# How many authors have published papers in journals before 2000 and cited papers published after 2020?
# SELECT COUNT(DISTINCT al.user_id)
# FROM author_list al
# JOIN publication_details pd1 ON al.publication_id = pd1.publication_id
# JOIN citation_details cd ON pd1.publication_id = cd.publication_id1
# JOIN publication_details pd2 ON cd.publication_id2 = pd2.publication_id
# WHERE pd1.journal_id IN (
#   SELECT journal_id
#   FROM publication_details
#   WHERE publication_date < '2000-01-01'
# )
# AND pd2.publication_date > '2020-12-31'
# 70
# ------------------
# How many publications are there that are cited by other publications in the journal named "Machine Learning Research"?
# "How many distinct publications have been cited in the Machine Learning Research journal?"
# SELECT COUNT(DISTINCT cd.publication_id2)
# FROM citation_details cd
# JOIN publication_details pd ON cd.publication_id2 = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE jd.journal_name = 'Machine Learning Research'
# 70
# ------------------
# Which journals have published papers co-authored by user "Michael" and the publication names have the word "neural network" in them?
# What are the names of the journals that Michael has published articles related to neural networks in?
# SELECT DISTINCT jd.journal_name
# FROM user_details ud
# JOIN author_list al ON ud.user_id = al.user_id
# JOIN publication_details pd ON al.publication_id = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE ud.user_name = 'Michael'
# AND pd.publication_name LIKE '%neural network%'
# 70
# ------------------
# How many publications are there that are cited by other publications in the journal named "Machine Learning Research"?
# "How many distinct publications have been cited in the Machine Learning Research journal?"
# SELECT COUNT(DISTINCT cd.publication_id2)
# FROM citation_details cd
# JOIN publication_details pd ON cd.publication_id2 = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE jd.journal_name = 'Machine Learning Research'
# 70
# ------------------
# Which journals have published papers co-authored by user "Michael" and the publication names have the word "neural network" in them?
# What are the names of the journals that Michael has published articles related to neural networks in?
# SELECT DISTINCT jd.journal_name
# FROM user_details ud
# JOIN author_list al ON ud.user_id = al.user_id
# JOIN publication_details pd ON al.publication_id = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE ud.user_name = 'Michael'
# AND pd.publication_name LIKE '%neural network%'
# 70
# ------------------
# How many publications are there that are cited by other publications in the journal named "Machine Learning Research"?
# "How many distinct publications have been cited in the Machine Learning Research journal?"
# SELECT COUNT(DISTINCT cd.publication_id2)
# FROM citation_details cd
# JOIN publication_details pd ON cd.publication_id2 = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE jd.journal_name = 'Machine Learning Research'
# 70
# ------------------
# Which journals have published papers co-authored by user "Michael" and the publication names have the word "neural network" in them?
# What are the names of the journals that Michael has published articles related to neural networks in?
# SELECT DISTINCT jd.journal_name
# FROM user_details ud
# JOIN author_list al ON ud.user_id = al.user_id
# JOIN publication_details pd ON al.publication_id = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE ud.user_name = 'Michael'
# AND pd.publication_name LIKE '%neural network%'
# 70
# ------------------
# How many publications are there that are cited by other publications in the journal named "Machine Learning Research"?
# "How many distinct publications have been cited in the Machine Learning Research journal?"
# SELECT COUNT(DISTINCT cd.publication_id2)
# FROM citation_details cd
# JOIN publication_details pd ON cd.publication_id2 = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE jd.journal_name = 'Machine Learning Research'
# 70
# ------------------
# Which journals have published papers co-authored by user "Michael" and the publication names have the word "neural network" in them?
# What are the names of the journals that Michael has published articles related to neural networks in?
# SELECT DISTINCT jd.journal_name
# FROM user_details ud
# JOIN author_list al ON ud.user_id = al.user_id
# JOIN publication_details pd ON al.publication_id = pd.publication_id
# JOIN journal_details jd ON pd.journal_id = jd.journal_id
# WHERE ud.user_name = 'Michael'
# AND pd.publication_name LIKE '%neural network%'
# 70
# ------------------
# failures rate:  0.3 15 50

# %% [markdown]
# So far, we asked LLM to generate questions given the table information! Howe can we increase diversity of questions? In other words, how can we generate any possible questions that a user might ask?
# We now use the metheod introduced in [AdaTest](https://aclanthology.org/2022.acl-long.230.pdf) and [Codev](https://arxiv.org/abs/2305.12219) to find a more diverse range of questions.
# Unlike previous methods, here the LLM generates new questions only given some previous questions (no table information is provided)! The goal is to generate questions that increase some score function (here the negative of correctness).
# For more details see Appendix of [AdaTest](https://aclanthology.org/2022.acl-long.230.pdf), or Algorithm 1 in [Codev](https://arxiv.org/abs/2305.12219).

# %%
import adatest

#adatest needs a generator that give k example it can generate more examples. 
with open(os.path.expanduser('~/.openai_api_key'), 'r') as file:
    OPENAI_API_KEY = file.read().replace('\n', '')
generator = adatest.generators.OpenAI('text-davinci-003', api_key=OPENAI_API_KEY)


#adatest needs a score function our goal is to find questions with maximum score
# we use the varialbe adatest_tests to store examples that their correctness are checked
adatest_tests = []
def scoring_fn(inputs):
    output = []
    for input in inputs:
        q = correctness(input)
        output.append(-q[3])
        adatest_tests.append(q)
    return output

def adatest_evaluation(num_rounds, q_in_each_round=10, max_suggestions=50):
    questions = generate_natrual_language_questions(table_info=table_info, 
                                                    num_questions=q_in_each_round, 
                                                    examples=None, 
                                                    contain_examples=False)
    #remove the question number from each question
    questions = questions['answer'].split('\n')
    questions = [q.split('. ', 1)[1] for q in questions]

    #we make a test_tree with the question and call auto_optimize function
    tests = adatest.TestTree(questions)
    ada_scorer = adatest.RawScorer(scoring_fn)
    adapter = tests.adapt(ada_scorer, generator, max_suggestions=max_suggestions)
    adapter.auto_optimize(num_rounds)
    tests_sorted = tests[tests['model score'] != '__TOEVAL__'].sort_values("model score", ascending=False)
    return tests_sorted

# %%
adatest_examples = adatest_evaluation(num_rounds=5, q_in_each_round=5, max_suggestions=10)
# Out:
# <div id="guidance-stop-button-345c7807-386c-46d8-bdb6-483db4f4fa7b" style="cursor: pointer; margin: 0px; display: none; float: right; padding: 3px; border-radius: 4px 4px 4px 4px; border: 0px solid rgba(127, 127, 127, 1); padding-left: 10px; padding-right: 10px; font-size: 13px; background-color: rgba(127, 127, 127, 0.25);">Stop program</div><div id="guidance-content-345c7807-386c-46d8-bdb6-483db4f4fa7b"><pre style='margin: 0px; padding: 0px; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are an expert for SQL.
# </div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>These are some information about tables in my database:
#
# --
# <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{table_info}}'>
# There are 5 tables in the database with the following information:
#
# Table name: user_details
# Table columns: user_id,  user_name
#
# Table name: journal_details
# Table columns: journal_id, journal_name
#
# Table name: publication_details
# Table columns: publication_id, publication_name, publication_date, journal_id
#
# Table name: author_list
# Table columns: user_id, publication_id
#
# Table name: citation_details
# Table columns: publication_id1, publication_id2
# table information: publication_id1 cites publication_id2
# </span>
# --
#
# what is the SQL program to answer this question?
# Question: <span style='background-color: rgba(0, 138.56128016, 250.76166089, 0.25); display: inline;' title='{{question}}'>Which publications have the highest impact factor in the area of Deep Learning?</span>
#
# Only write down the sql code no other text.
# If you cannot generate a SQL program for this question then write down &quot;out of scope&quot;
# </div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0, 165, 0, 0.25); opacity: 1.0; display: inline;' title='{{gen &#x27;answer&#x27;}}'>out of scope</span></div></div></pre></div>
# <script type="text/javascript">(()=>{var t={296:(t,e,n)=>{var i=NaN,o="[object Symbol]",r=/^\s+|\s+$/g,a=/^[-+]0x[0-9a-f]+$/i,s=/^0b[01]+$/i,c=/^0o[0-7]+$/i,d=parseInt,u="object"==typeof n.g&&n.g&&n.g.Object===Object&&n.g,l="object"==typeof self&&self&&self.Object===Object&&self,f=u||l||Function("return this")(),h=Object.prototype.toString,p=Math.max,m=Math.min,g=function(){return f.Date.now()};function b(t){var e=typeof t;return!!t&&("object"==e||"function"==e)}function y(t){if("number"==typeof t)return t;if(function(t){return"symbol"==typeof t||function(t){return!!t&&"object"==typeof t}(t)&&h.call(t)==o}(t))return i;if(b(t)){var e="function"==typeof t.valueOf?t.valueOf():t;t=b(e)?e+"":e}if("string"!=typeof t)return 0===t?t:+t;t=t.replace(r,"");var n=s.test(t);return n||c.test(t)?d(t.slice(2),n?2:8):a.test(t)?i:+t}t.exports=function(t,e,n){var i,o,r,a,s,c,d=0,u=!1,l=!1,f=!0;if("function"!=typeof t)throw new TypeError("Expected a function");function h(e){var n=i,r=o;return i=o=void 0,d=e,a=t.apply(r,n)}function v(t){var n=t-c;return void 0===c||n>=e||n<0||l&&t-d>=r}function _(){var t=g();if(v(t))return w(t);s=setTimeout(_,function(t){var n=e-(t-c);return l?m(n,r-(t-d)):n}(t))}function w(t){return s=void 0,f&&i?h(t):(i=o=void 0,a)}function j(){var t=g(),n=v(t);if(i=arguments,o=this,c=t,n){if(void 0===s)return function(t){return d=t,s=setTimeout(_,e),u?h(t):a}(c);if(l)return s=setTimeout(_,e),h(c)}return void 0===s&&(s=setTimeout(_,e)),a}return e=y(e)||0,b(n)&&(u=!!n.leading,r=(l="maxWait"in n)?p(y(n.maxWait)||0,e):r,f="trailing"in n?!!n.trailing:f),j.cancel=function(){void 0!==s&&clearTimeout(s),d=0,i=c=o=s=void 0},j.flush=function(){return void 0===s?a:w(g())},j}},777:t=>{var e,n,i=Math.max,o=(e=function(t,e){return function(t,e,n){if("function"!=typeof t)throw new TypeError("Expected a function");return setTimeout((function(){t.apply(void 0,n)}),1)}(t,0,e)},n=i(void 0===n?e.length-1:n,0),function(){for(var t=arguments,o=-1,r=i(t.length-n,0),a=Array(r);++o<r;)a[o]=t[n+o];o=-1;for(var s=Array(n+1);++o<n;)s[o]=t[o];return s[n]=a,function(t,e,n){switch(n.length){case 0:return t.call(e);case 1:return t.call(e,n[0]);case 2:return t.call(e,n[0],n[1]);case 3:return t.call(e,n[0],n[1],n[2])}return t.apply(e,n)}(e,this,s)});t.exports=o}},e={};function n(i){var o=e[i];if(void 0!==o)return o.exports;var r=e[i]={exports:{}};return t[i](r,r.exports,n),r.exports}n.n=t=>{var e=t&&t.__esModule?()=>t.default:()=>t;return n.d(e,{a:e}),e},n.d=(t,e)=>{for(var i in e)n.o(e,i)&&!n.o(t,i)&&Object.defineProperty(t,i,{enumerable:!0,get:e[i]})},n.g=function(){if("object"==typeof globalThis)return globalThis;try{return this||new Function("return this")()}catch(t){if("object"==typeof window)return window}}(),n.o=(t,e)=>Object.prototype.hasOwnProperty.call(t,e),(()=>{"use strict";const t=t=>{const e=new Set;do{for(const n of Reflect.ownKeys(t))e.add([t,n])}while((t=Reflect.getPrototypeOf(t))&&t!==Object.prototype);return e};function e(e,{include:n,exclude:i}={}){const o=t=>{const e=e=>"string"==typeof e?t===e:e.test(t);return n?n.some(e):!i||!i.some(e)};for(const[n,i]of t(e.constructor.prototype)){if("constructor"===i||!o(i))continue;const t=Reflect.getOwnPropertyDescriptor(n,i);t&&"function"==typeof t.value&&(e[i]=e[i].bind(e))}return e}var i=n(777),o=n.n(i),r=n(296),a=n.n(r);class s{constructor(t,n){e(this),this.interfaceId=t,this.callbackMap={},this.data={},this.pendingData={},this.jcomm=new c("guidance_interface_target_"+this.interfaceId,this.updateData,"open"),this.debouncedSendPendingData500=a()(this.sendPendingData,500),this.debouncedSendPendingData1000=a()(this.sendPendingData,1e3),n&&o()(n)}send(t,e){this.addPendingData(t,e),this.sendPendingData()}sendEvent(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.sendPendingData()}debouncedSendEvent500(t){for(const e of Object.keys(t))this.addPendingData(e,t[e]);this.debouncedSendPendingData500()}debouncedSend500(t,e){this.addPendingData(t,e),this.debouncedSendPendingData500()}debouncedS ...
# 100%|██████████| 5/5 [02:19<00:00, 27.82s/it]
# the generated sql:
#  out of scope

# %%
investigate(adatest_tests)
# Out:
# What types of research have been done in the area of Natural Language Processing?
# "Can you show me a list of distinct publication names related to the journal 'Natural Language Processing' that were authored by any user in the database?"
# SELECT DISTINCT publication_name
# FROM publication_details
# WHERE journal_id IN (
#   SELECT journal_id
#   FROM journal_details
#   WHERE journal_name = 'Natural Language Processing'
# )
# AND publication_id IN (
#   SELECT publication_id
#   FROM author_list
#   WHERE user_id IN (
#     SELECT user_id
#     FROM user_details
#   )
# )
# ORDER BY publication_name;
# 30
# ------------------
# What is the impact factor of the journal 'Bioinformatics'?
# How many citations are there for publications in the journal "Bioinformatics"?
# SELECT COUNT(*) AS total_citations
# FROM citation_details
# WHERE publication_id2 IN (
#   SELECT publication_id
#   FROM publication_details
#   WHERE journal_id = (
#     SELECT journal_id
#     FROM journal_details
#     WHERE journal_name = 'Bioinformatics'
#   )
# );
# 50
# ------------------
# What is the average number of authors in all publications related to Machine Learning?
# What is the average number of authors per publication in journals with "Machine Learning" in their name?
# SELECT AVG(author_count) AS avg_authors
# FROM (
#   SELECT COUNT(user_id) AS author_count
#   FROM author_list
#   INNER JOIN publication_details ON author_list.publication_id = publication_details.publication_id
#   INNER JOIN journal_details ON publication_details.journal_id = journal_details.journal_id
#   WHERE journal_details.journal_name LIKE '%Machine Learning%'
#   GROUP BY author_list.publication_id
# ) AS subquery
# 50
# ------------------
# What is the average number of citations of publications related to 'Sentiment #!%@ysis'?
# What is the average number of citations for publications that cite any publication with "Sentiment #!%@ysis" in its name?
# SELECT AVG(citation_count) AS avg_citations
# FROM (
#   SELECT COUNT(*) AS citation_count
#   FROM citation_details
#   WHERE publication_id2 IN (
#     SELECT publication_id
#     FROM publication_details
#     WHERE publication_name LIKE '%Sentiment #!%@ysis%'
#   )
#   GROUP BY publication_id1
# ) AS citation_counts;
# 50
# ------------------
# What are the most important keywords related to publications on Natural Language Processing?
# What are the publications related to Natural Language Processing and who are the authors?
# SELECT publication_name
# FROM publication_details
# WHERE publication_id IN
#     (SELECT publication_id
#      FROM author_list
#      WHERE user_id IN
#          (SELECT user_id
#           FROM user_details
#           WHERE user_name LIKE '%Natural Language Processing%'))
# 50
# ------------------
# What are the names of the journals that have publications authored by both 'JaneDoe' and 'JohnDoe'?
# What are the journals that JaneDoe has published in that are also published in by JohnDoe?
# SELECT DISTINCT j.journal_name
# FROM journal_details j
# INNER JOIN publication_details p ON j.journal_id = p.journal_id
# INNER JOIN author_list a ON p.publication_id = a.publication_id
# INNER JOIN user_details u ON a.user_id = u.user_id
# WHERE u.user_name = 'JaneDoe' AND j.journal_name IN (
#     SELECT j2.journal_name
#     FROM journal_details j2
#     INNER JOIN publication_details p2 ON j2.journal_id = p2.journal_id
#     INNER JOIN author_list a2 ON p2.publication_id = a2.publication_id
#     INNER JOIN user_details u2 ON a2.user_id = u2.user_id
#     WHERE u2.user_name = 'JohnDoe'
# )
# 70
# ------------------
# What is the user name of the author who authored the most number of publications?
# Who is the most prolific author in the database?
# SELECT user_details.user_name
# FROM user_details
# JOIN author_list ON user_details.user_id = author_list.user_id
# GROUP BY user_details.user_id
# ORDER BY COUNT(author_list.publication_id) DESC
# LIMIT 1;
# 70
# ------------------
# What is the most frequently cited publication in the field of Machine Learning?
# What is the publication with the highest number of citations?
# SELECT publication_id2, COUNT(*) AS citation_count
# FROM citation_details
# GROUP BY publication_id2
# ORDER BY citation_count DESC
# LIMIT 1;
# 70
# ------------------
# What are the titles of the publications co-authored by 'JohnDoe'?
# What are the publications that John Doe has authored?
# SELECT publication_name
# FROM publication_details
# INNER JOIN author_list ON publication_details.publication_id = author_list.publication_id
# INNER JOIN user_details ON author_list.user_id = user_details.user_id
# WHERE user_name = 'JohnDoe'
# 70
# ------------------
# How many publications have been published in the 'Artificial Intelligence Research' journal since 2019?
# "How many publications related to Artificial Intelligence Research have been published since January 1st, 2019?"
# SELECT COUNT(*)
# FROM publication_details
# WHERE journal_id = (SELECT journal_id FROM journal_details WHERE journal_name = 'Artificial Intelligence Research')
# AND publication_date >= '2019-01-01';
# 70
# ------------------
# Which publications have been cited by at least 10 other publications?
# Which publications have been cited at least 10 times?
# SELECT publication_id2, COUNT(*) as citation_count
# FROM citation_details
# GROUP BY publication_id2
# HAVING COUNT(*) >= 10;
# 70
# ------------------
# What is the average number of citations for the publications authored by 'SarahSmith'?
# What is the average number of citations for publications where Sarah Smith is listed as an author?
# SELECT AVG(citation_count) AS avg_citations
# FROM (
#   SELECT COUNT(*) AS citation_count
#   FROM citation_details
#   WHERE publication_id2 IN (
#     SELECT publication_id
#     FROM author_list
#     JOIN user_details ON author_list.user_id = user_details.user_id
#     WHERE user_name = 'SarahSmith'
#   )
#   GROUP BY publication_id1
# ) AS citation_counts;
# 70
# ------------------
# What is the average citation count of the publications authored by 'AliceJones'?
# What is the average citation count for publications where AliceJones is listed as an author?
# SELECT AVG(citation_count) AS avg_citation_count
# FROM (
#   SELECT COUNT(*) AS citation_count
#   FROM citation_details
#   WHERE publication_id2 IN (
#     SELECT publication_id
#     FROM author_list
#     INNER JOIN user_details ON author_list.user_id = user_details.user_id
#     WHERE user_name = 'AliceJones'
#   )
#   GROUP BY publication_id1
# ) AS citation_counts;
# 70
# ------------------
# What is the average number of authors of the publications related to 'Deep Learning'?
# What is the average number of authors per publication for publications with "Deep Learning" in their name?
# SELECT AVG(author_count) AS avg_authors
# FROM (
#   SELECT COUNT(user_id) AS author_count
#   FROM author_list
#   WHERE publication_id IN (
#     SELECT publication_id
#     FROM publication_details
#     WHERE publication_name LIKE '%Deep Learning%'
#   )
#   GROUP BY publication_id
# ) AS subquery;
# 70
# ------------------
# What are the most influential research publications in the area of Natural Language Processing?
# What are the top 10 most cited publications and their citation counts?
# SELECT publication_name, COUNT(*) AS citation_count
# FROM publication_details
# JOIN citation_details ON publication_details.publication_id = citation_details.publication_id2
# GROUP BY publication_details.publication_id
# ORDER BY citation_count DESC
# LIMIT 10;
# 70
# ------------------
# Who are the top authors in the field of Natural Language Processing?
# "Which users have published the most articles in the field of Natural Language Processing and how many articles have they published?"
# SELECT user_details.user_name, COUNT(*) as num_publications
# FROM user_details
# JOIN author_list ON user_details.user_id = author_list.user_id
# JOIN publication_details ON author_list.publication_id = publication_details.publication_id
# JOIN journal_details ON publication_details.journal_id = journal_details.journal_id
# WHERE journal_details.journal_name = 'Natural Language Processing'
# GROUP BY user_details.user_name
# ORDER BY num_publications DESC
# LIMIT 10;
# 70
# ------------------
# What publications have the highest impact on Natural Language Processing?
# "Can you show me a list of publications and their citation count in the journal 'Natural Language Processing' ordered by the citation count in descending order?"
# SELECT publication_name, COUNT(*) AS citation_count
# FROM citation_details
# JOIN publication_details ON citation_details.publication_id2 = publication_details.publication_id
# WHERE publication_details.journal_id = (SELECT journal_id FROM journal_details WHERE journal_name = 'Natural Language Processing')
# GROUP BY publication_name
# ORDER BY citation_count DESC;
# 70
# ------------------
# What is the average number of authors per publication in the area of Natural Language Processing?
# What is the average number of authors per publication in the journal "Natural Language Processing"?
# SELECT AVG(author_count) AS avg_authors_per_publication
# FROM (
#   SELECT COUNT(user_id) AS author_count
#   FROM author_list
#   INNER JOIN publication_details ON author_list.publication_id = publication_details.publication_id
#   INNER JOIN journal_details ON publication_details.journal_id = journal_details.journal_id
#   WHERE journal_details.journal_name = 'Natural Language Processing'
#   GROUP BY author_list.publication_id
# ) AS author_counts;
# 70
# ------------------
# What is the average number of citations for the publications related to 'Natural Language Processing'?
# What is the average number of citations for publications that cite any publication related to Natural Language Processing?
# SELECT AVG(citation_count) AS avg_citations
# FROM (
#   SELECT COUNT(*) AS citation_count
#   FROM citation_details
#   WHERE publication_id2 IN (
#     SELECT publication_id
#     FROM publication_details
#     WHERE publication_name LIKE '%Natural Language Processing%'
#   )
#   GROUP BY publication_id1
# ) AS citation_counts;
# 70
# ------------------
# Who are the leading authors in the field of Artificial Intelligence?
# Which users have the highest citation count for publications related to Artificial Intelligence?
# SELECT user_details.user_name, COUNT(*) as citation_count
# FROM user_details
# JOIN author_list ON user_details.user_id = author_list.user_id
# JOIN citation_details ON author_list.publication_id = citation_details.publication_id2
# JOIN publication_details ON citation_details.publication_id1 = publication_details.publication_id
# WHERE publication_details.publication_name LIKE '%Artificial Intelligence%'
# GROUP BY user_details.user_name
# ORDER BY citation_count DESC
# LIMIT 10;
# 70
# ------------------
# What are the top five research publications in the field of Deep Learning?
# What are the top 5 most cited publications related to Deep Learning?
# SELECT publication_name, COUNT(*) AS citation_count
# FROM citation_details
# JOIN publication_details ON citation_details.publication_id2 = publication_details.publication_id
# WHERE publication_details.publication_name LIKE '%Deep Learning%'
# GROUP BY citation_details.publication_id2
# ORDER BY citation_count DESC
# LIMIT 5;
# 70
# ------------------
# Which authors have published the most in the field of Natural Language Processing?
# Which user has the highest number of publications in the journal "Natural Language Processing"?
# SELECT user_details.user_name, COUNT(*) AS num_publications
# FROM user_details
# JOIN author_list ON user_details.user_id = author_list.user_id
# JOIN publication_details ON author_list.publication_id = publication_details.publication_id
# JOIN journal_details ON publication_details.journal_id = journal_details.journal_id
# WHERE journal_details.journal_name = 'Natural Language Processing'
# GROUP BY user_details.user_name
# ORDER BY num_publications DESC
# LIMIT 1;
# 70
# ------------------
# Which authors have published the most research papers in the area of Natural Language Processing?
# Which user has the highest number of papers published in the journal "Natural Language Processing"?
# SELECT user_details.user_name, COUNT(publication_details.publication_id) AS num_papers
# FROM user_details
# JOIN author_list ON user_details.user_id = author_list.user_id
# JOIN publication_details ON author_list.publication_id = publication_details.publication_id
# JOIN journal_details ON publication_details.journal_id = journal_details.journal_id
# WHERE journal_details.journal_name = 'Natural Language Processing'
# GROUP BY user_details.user_name
# ORDER BY num_papers DESC
# LIMIT 1;
# 70
# ------------------
# Who are the top authors in Natural Language Processing research?
# "Which users have published the most articles in the field of Natural Language Processing and how many articles have they published?"
# SELECT user_details.user_name, COUNT(*) as num_publications
# FROM user_details
# JOIN author_list ON user_details.user_id = author_list.user_id
# JOIN publication_details ON author_list.publication_id = publication_details.publication_id
# JOIN journal_details ON publication_details.journal_id = journal_details.journal_id
# WHERE journal_details.journal_name = 'Natural Language Processing'
# GROUP BY user_details.user_name
# ORDER BY num_publications DESC
# LIMIT 10;
# 70
# ------------------
# failures rate:  0.4444444444444444 24 54

# %% [markdown]
# As you can see we can reach mugh higher failure rate and can find questions such as:
#
# | <!-- -->    | <!-- -->    |
# | ----------- | ----------- |
# | Question: | What is the average number of authors in all publications related to Machine Learning? |
# | Reverse Question: | What is the average number of authors per publication in journals with "Machine Learning" in their name? |
# | <!-- -->    | <!-- -->    |
# |Question: | What is the impact factor of the journal 'Bioinformatics'?|
# | Reverse Question: |How many citations are there for publications in the journal "Bioinformatics"?|
#
# Where the prompt decides that "publication related to machine learning" means publications in journal with "machine learning" in the name. or it wrongfully assumes impact factor means number of citations, etc. In these cases, the developers should make a decision on how do they want to handle such questions.
# In general, each failure can stem on NL_translator, SQL_transaltor, or similarity_checker and user should fix these prompts iteratively to reach a good NL_translator with low failure rate.
#
# You can connect failure finder to GUI and categorize erorrs with some tweaks using the [AdaTest repository](https://github.com/microsoft/adatest)
